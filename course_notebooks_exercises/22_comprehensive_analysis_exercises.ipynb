# %% [markdown]
# # Day 4: Comprehensive Analysis Exercise - EXERCISES
#
# ## Scenario: Multi-Quarter Sales Analysis
#
# You're a data analyst tasked with analyzing sales performance. This exercise brings together all skills from the course.
#
# **Skills Applied:**
# - Loading and merging data
# - Data cleaning and transformation
# - Date/time analysis
# - GroupBy and aggregation
# - Pivot tables
# - Visualization
# - Exporting results
#
# ---

# %% [markdown]
# ## Step 1: Load and Inspect the Data

# %%
# Setup: Create Sample Data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

np.random.seed(42)

# Generate dates and transactions
dates = pd.date_range('2023-01-01', '2024-12-31', freq='D')
n_transactions = 500

# Create transactions DataFrame
transactions = pd.DataFrame({
    'TransactionID': [f'TXN-{i:04d}' for i in range(1, n_transactions+1)],
    'Date': np.random.choice(dates, n_transactions),
    'CustomerID': np.random.choice([f'CUST-{i:03d}' for i in range(1, 51)], n_transactions),
    'ProductID': np.random.choice([f'PROD-{i:03d}' for i in range(1, 11)], n_transactions),
    'Quantity': np.random.randint(1, 10, n_transactions),
    'Amount': np.random.randint(500, 5000, n_transactions)
})

# Create customer data
customers = pd.DataFrame({
    'CustomerID': [f'CUST-{i:03d}' for i in range(1, 51)],
    'CustomerName': [f'Customer {i}' for i in range(1, 51)],
    'Region': np.random.choice(['EMEA', 'AMER', 'APAC'], 50),
    'CustomerType': np.random.choice(['Premium', 'Standard', 'Basic'], 50, p=[0.2, 0.5, 0.3])
})

# Create product data
products = pd.DataFrame({
    'ProductID': [f'PROD-{i:03d}' for i in range(1, 11)],
    'ProductName': ['Suite A', 'Suite B', 'Analytics', 'Premium', 'Basic', 
                    'Enterprise', 'Starter', 'Pro', 'Ultimate', 'Lite'],
    'Category': np.random.choice(['Software', 'Services', 'Hardware'], 10),
    'Price': [199, 99, 299, 499, 49, 599, 79, 249, 799, 39],
    'Cost': [80, 45, 130, 220, 20, 260, 35, 110, 350, 18]
})

print("Data loaded!")
print(f"Transactions: {len(transactions)} rows")
print(f"Customers: {len(customers)} rows")
print(f"Products: {len(products)} rows")

# %% [markdown]
# ### Task 1.1: Inspect the Data

# %%
# Task 1.1: Inspect Each Dataset
# Use .head() and .dtypes to understand the data

# Your code here:
# Print the first few rows and data types for each dataset

# %% [markdown]
# ---
# ## Step 2: Clean and Prepare Data

# %%
# Task 2.1: Convert Date Column to Datetime
# The Date column is currently a string - convert it to datetime

# Your code here:

# %%
# Task 2.2: Check for Missing Values
# Check all datasets for missing data

# Your code here:

# %% [markdown]
# ---
# ## Step 3: Integrate the Data

# %%
# Task 3.1: Join Transactions with Customers
# Merge on CustomerID using a left join

# Your code here:

# %%
# Task 3.2: Join with Products
# Continue the merge chain to add product information

# Your code here:

# %%
# Task 3.3: Calculate Additional Metrics
# Create new columns:
# - TotalRevenue = Quantity * Price
# - TotalCost = Quantity * Cost
# - Profit = TotalRevenue - TotalCost
# - ProfitMargin% = (Profit / TotalRevenue) * 100

# Your code here:

# %% [markdown]
# ---
# ## Step 4: Time-Based Analysis

# %%
# Task 4.1: Extract Date Components
# Extract: Year, Quarter, Month, MonthName from the Date column

# Your code here:
# Use the .dt accessor to extract date components

# %%
# Task 4.2: Monthly Revenue Trend
# Group by month and calculate total revenue

# Your code here:
# Hint: Use df['Date'].dt.to_period('M') for monthly grouping

# %% [markdown]
# ---
# ## Step 5: Business Intelligence Queries

# %%
# Task 5.1: Regional Performance
# Group by Region and calculate: Total Revenue, Total Profit, Avg Margin%, Transaction Count

# Your code here:
# Use .agg() with multiple aggregation functions

# %%
# Task 5.2: Top 5 Products
# Group by ProductName, calculate Revenue, Profit, Units Sold
# Sort by Revenue and get top 5

# Your code here:

# %% [markdown]
# ---
# ## Step 6: Create Pivot Tables

# %%
# Task 6.1: Region × Product Revenue Pivot
# Create a pivot table showing revenue by Region and Product
# Include totals and fill missing values with 0

# Your code here:

# %%
# Task 6.2: Quarterly Performance Pivot
# Create YearQuarter label and build pivot by Region

# Your code here:
# Step 1: Create YearQuarter column (format: "2023 Q1")


# Step 2: Create pivot table with quarters as rows, regions as columns

# %% [markdown]
# ---
# ## Step 7: Visualize Key Insights

# %%
# Task 7.1: Monthly Revenue Trend Chart
# Create a line chart showing the monthly revenue trend

# Your code here:
# Plot the monthly_revenue with markers and grid

# %%
# Task 7.2: Create a 2x2 Dashboard
# Build 4 charts: Revenue by Region, Profit by Region, Top Products, Customer Type Revenue

# Your code here:
# Create a 2x2 subplot grid and populate with 4 different charts

# %% [markdown]
# ---
# ## Step 8: Export Results

# %%
# Task 8.1: Export Multi-Sheet Excel Report
# Create an Excel file with multiple sheets: Summary, Regional, Products, Pivot

# Your code here:
# Use pd.ExcelWriter to create multi-sheet workbook
# Include:
# - Summary sheet with key metrics
# - Regional performance sheet
# - Product performance sheet
# - Pivot table sheet

# %% [markdown]
# ---
# ## Summary
#
# **Congratulations!** You've completed a comprehensive data analysis project.
#
# ### Skills Applied:
# - Data loading and integration (joins)
# - Data cleaning and preparation
# - Date/time manipulation
# - GroupBy and aggregation
# - Pivot tables
# - Data visualization
# - Excel export
#
# **You're now ready to tackle real-world data analysis projects!**
