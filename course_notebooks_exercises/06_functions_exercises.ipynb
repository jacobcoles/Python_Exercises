# %% [markdown]
# # Day 1: Functions Introduction - EXERCISES
#
# ## Learning Objectives
# - Define and call basic functions
# - Use parameters and return values
# - Return multiple values
# - Write docstrings
#
# ---

# %% [markdown]
# ## 1. Function Basics

# %%
# Demo: Simple function
def welcome_message():
    print("Welcome to Data Analytics!")
    print("Let's analyze some business data.")

# Call the function
welcome_message()

# %% [markdown]
# ### Exercise 1: Create Your First Function
#
# Create a function that prints company information.

# %%
# Exercise 1: Create Your First Function
# Task: Define a function that prints company information
# Hint: Use 'def function_name():' then indent the body (see demo above)

# Your code here:
# 1. Define a function called print_company_info()
# 2. Inside the function, print three lines:
#    - Company name
#    - Department
#    - A message
# 3. Call the function

# %% [markdown]
# ---
# ## 2. Parameters and Return Values

# %%
# Demo: Function with parameters and return
def calculate_margin(revenue, cost):
    profit = revenue - cost
    margin_percent = (profit / revenue) * 100
    return margin_percent

# Use the returned value
margin = calculate_margin(5000, 3200)
print(f"Margin: {margin:.1f}%")

# %% [markdown]
# ### Exercise 2: Create a Function with Parameters and Return
#
# Create a function that calculates discounted price.

# %%
# Exercise 2: Calculate Discounted Price
# Task: Create a function that returns the discounted price
# Hint: Define parameters, calculate result, use 'return' to send value back (see demo above)

# Your code here:
# 1. Define function: calculate_discount_price(original_price, discount_percent)
# 2. Calculate discount_amount: original_price × (discount_percent ÷ 100)
# 3. Calculate final_price: original_price - discount_amount
# 4. Return final_price
# 5. Test with: calculate_discount_price(199, 15) and calculate_discount_price(499, 25)
# 6. Print both results with formatting

# %% [markdown]
# ---
# ## 3. Returning Multiple Values

# %%
# Demo: Returning multiple values
def analyze_transaction(amount, tax_rate):
    tax = amount * tax_rate
    total = amount + tax
    return tax, total  # Returns a tuple

# Unpack the returned values
transaction_tax, transaction_total = analyze_transaction(1000, 0.20)

print(f"Tax: €{transaction_tax:.2f}")
print(f"Total: €{transaction_total:.2f}")

# %% [markdown]
# ### Exercise 3: Create a Function Returning Multiple Values
#
# Create a function that analyzes an order and returns subtotal, discount, and total.

# %%
# Exercise 3: Function Returning Multiple Values
# Task: Analyze order and return three values
# Hint: Return multiple values separated by commas (see demo above)

# Your code here:
# 1. Define function: analyze_order(unit_price, quantity, discount_percent)
# 2. Calculate subtotal: unit_price × quantity
# 3. Calculate discount_amount: subtotal × (discount_percent ÷ 100)
# 4. Calculate total: subtotal - discount_amount
# 5. Return all three values: subtotal, discount_amount, total
# 6. Test with: analyze_order(49.99, 10, 12)
# 7. Unpack into three variables and print each

# %% [markdown]
# ---
# ## 4. Documenting Functions with Docstrings

# %%
# Demo: Docstring
def calculate_commission(sales_amount, commission_rate):
    """
    Calculate sales commission.
    
    Parameters:
    sales_amount (float): Total sales value
    commission_rate (float): Rate as decimal (0.05 = 5%)
    
    Returns:
    float: Commission amount
    """
    return sales_amount * commission_rate

# Test
commission = calculate_commission(25000, 0.08)
print(f"Commission (8%): €{commission:,.2f}")

# %% [markdown]
# ### Exercise 4: Create a Documented Function
#
# Create a currency conversion function with a complete docstring.

# %%
# Exercise 4: Create a Documented Function
# Task: Convert euros to another currency with documentation
# Hint: Use triple quotes for docstring right after def line (see demo above)

# Your code here:
# 1. Define function: convert_currency(amount_eur, exchange_rate)
# 2. Add docstring explaining parameters and return value
# 3. Calculate: converted_amount = amount_eur × exchange_rate
# 4. Return converted_amount
# 5. Test with: convert_currency(5000, 1.12)
# 6. Print result with formatting

# %% [markdown]
# ---
# ## Challenge Exercise: Business Calculator
#
# Create four functions that work together:
# 1. `calculate_revenue(units, price)` - returns revenue
# 2. `calculate_costs(units, cost_per_unit, fixed_costs)` - returns total costs
# 3. `calculate_profit(revenue, costs)` - returns profit
# 4. `analyze_deal(...)` - uses the above and returns all metrics

# %%
# Challenge Exercise: Business Calculator
# Task: Create four functions that work together
# Hint: Call one function from inside another to compose functionality

# Your code here:
# Function 1: calculate_revenue(units, price)
#   - Return units × price

# Function 2: calculate_costs(units, cost_per_unit, fixed_costs)
#   - Calculate variable_costs = units × cost_per_unit
#   - Return variable_costs + fixed_costs

# Function 3: calculate_profit(revenue, costs)
#   - Return revenue - costs

# Function 4: analyze_deal(units, price, cost_per_unit, fixed_costs)
#   - Call calculate_revenue() to get revenue
#   - Call calculate_costs() to get costs
#   - Call calculate_profit() to get profit
#   - Calculate margin: (profit ÷ revenue) × 100
#   - Return revenue, costs, profit, margin

# Test with: analyze_deal(500, 149, 82, 12000)
# Unpack the four returned values and print the formatted report

print("=" * 50)
print("DEAL ANALYSIS")
print("=" * 50)
# Add your calculations and print statements here
print("=" * 50)

# %% [markdown]
# ---
# ## Summary
#
# **You've learned:**
# - ✓ Defining and calling functions
# - ✓ Parameters for flexible input
# - ✓ Return values (single and multiple)
# - ✓ Docstrings for documentation
# - ✓ Composing functions together
#
# **Congratulations on completing Day 1!**
